# %%
import matplotlib
import matplotlib.pyplot as plt
import QgasFunctions as qFunc
import numpy as np
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
x=np.linspace(0,100,100)
y=np.linspace(0,100,100)
[xx,yy]=meshgrid(y,x)
xyval = (xx, yy)

# %%
import QgasFunctions as qFunc
threeThermal = qFunc.puck2DSG(xyval,pp)
fig = plt.figure()
ax = plt.gca()
aa = ax.imshow(threeThermal)

# %%
pp = ([20,60], [50,50], [80,25], [20, 20], [0.5,0.2,0.6])

# %%
threeThermal = qFunc.Thermal2DSG(xyval,pp)

# %%
fig = plt.figure()
ax = plt.gca()
aa = ax.imshow(threeThermal)

# %%
from scipy import interpolate
x = np.arange(0, 10)
y = np.exp(-x/3.0)
f = interpolate.interp1d(x, y)

xnew = np.arange(0,9, 0.1)
ynew = f(xnew)   # use interpolation function returned by `interp1d`
plt.plot(x, y, 'o', xnew, ynew, '-')
plt.show()

# %%
from scipy.interpolate import interp1d

# %%
intm = interp1d(x,y,bounds_error = False, fill_value = 0.0)

# %%
print intm

# %%
intm(x+2)
# Out:
# array([ 0.51341712,  0.36787944,  0.26359714,  0.1888756 ,  0.13533528,
#         0.09697197,  0.06948345,  0.04978707,  0.        ,  0.        ])

# %%
plt.plot(x,y,'o',x-2,intm(x-2),'-')
